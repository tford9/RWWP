# %%
import networkx as nx, pandas as pd, subprocess, os, time, math

# %%
import subprocess, os
os.environ["DYLD_LIBRARY_PATH"] = "/Users/trentonford/Desktop/KERNAL_PROJECT_SPACE/usr/lib:"+ os.environ["DYLD_LIBRARY_PATH"];
my_env = os.environ.copy()
my_env["PATH"] = "/Users/trentonford/Desktop/KERNAL_PROJECT_SPACE/usr/bin:" + my_env["PATH"]
# my_env['DYLD_LIBRARY_PATH'] = "/Users/trentonford/Desktop/KERNAL_PROJECT_SPACE/usr/lib:"+ my_env['DYLD_LIBRARY_PATH']

# %% [markdown]
# ## Erdos Renyi Graph Generation

# %%
scaling_data = pd.DataFrame(columns=['TYPE', 'ORDER', 'SIZE', 'WALL', 'CPU', 'RESULT'])
for x in range(0,2):
    for i in range(1,10,1):
        G = nx.erdos_renyi_graph(10*i, 10**(-1), seed=None, directed=True)
        print(G.order())
        nx.write_edgelist(G, path=str('../graph_data/processed/current_g'), data=False, delimiter='\t')
        WALL_START, CPU_START = time.time(), time.clock()
        p = subprocess.Popen(["/Users/trentonford/Repositories/RWWP/seq/./main"], stdout=subprocess.PIPE, shell=False, env=my_env)

        (output, err) = p.communicate()

        p_status = p.wait()
        WALL_END, CPU_END = time.time(), time.clock()

        scaling_data_row = pd.DataFrame([["ERDOS_RENYI", G.order(), G.size() ,WALL_END - WALL_START, CPU_END-CPU_START, output]], columns=['TYPE', 'ORDER', 'SIZE', 'WALL', 'CPU', 'RESULT'])
        scaling_data = scaling_data.append(scaling_data_row);

        print ("Command output : ", output)
        print ("Command exit status/return code : ", p_status)
# Out:
# 10
# Command output :  b'Consistancy_Check Success! All Uninfected!\n'
# Command exit status/return code :  0
# 20
# /Users/trentonford/Repositories/python3_7/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   import sys
# /Users/trentonford/Repositories/python3_7/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   del sys.path[0]
# Command output :  b'Consistancy_Check Success! All Uninfected!\n'
# Command exit status/return code :  0
# 30
# Command output :  b'Consistancy_Check Success! All Uninfected!\n'
# Command exit status/return code :  0
# 40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-818ec042bf40> in <module>
#       8         p = subprocess.Popen(["/Users/trentonford/Repositories/RWWP/seq/./main"], stdout=subprocess.PIPE, shell=False, env=my_env)
#       9
# ---> 10         (output, err) = p.communicate()
#      11
#      12         p_status = p.wait()
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     905                 self._stdin_write(input)
#     906             elif self.stdout:
# --> 907                 stdout = self.stdout.read()
#     908                 self.stdout.close()
#     909             elif self.stderr:
#
# KeyboardInterrupt:

# %%
scaling_data.reset_index(inplace=True)
scaling_data.drop(columns='index', inplace=True)
display(scaling_data)
scaling_data.to_pickle('1000_ERDOS_RENYI_Scaling_data')
scaling_data.groupby(['ORDER','SIZE']).agg(['mean', 'max'])
# Out:
#            TYPE ORDER  SIZE         WALL       CPU  \
# 0   ERDOS_RENYI    10     8     0.033761  0.005879
# 1   ERDOS_RENYI    20    39     0.043434  0.004316
# 2   ERDOS_RENYI    30    86     0.172633  0.008902
# 3   ERDOS_RENYI    40   146     3.141817  0.007865
# 4   ERDOS_RENYI    50   229     0.812128  0.008145
# 5   ERDOS_RENYI    60   367   134.515531  0.012911
# 6   ERDOS_RENYI    70   501  1059.856286  0.043646
# 7   ERDOS_RENYI    80   617   679.230123  0.031596
# 8   ERDOS_RENYI    90   776    20.650742  0.008465
# 9   ERDOS_RENYI   100  1010    28.810889  0.009948
# 10  ERDOS_RENYI   110  1250     0.030857  0.006732
# 11  ERDOS_RENYI   120  1425     0.172595  0.007932
#
#                                              RESULT
# 0   b'Consistancy_Check Success! All Uninfected!\n'
# 1   b'Consistancy_Check Success! All Uninfected!\n'
# 2   b'Consistancy_Check Success! All Uninfected!\n'
# 3     b'Consistancy_Check Success! All Infected!\n'
# 4     b'Consistancy_Check Success! All Infected!\n'
# 5     b'Consistancy_Check Success! All Infected!\n'
# 6     b'Consistancy_Check Success! All Infected!\n'
# 7     b'Consistancy_Check Success! All Infected!\n'
# 8     b'Consistancy_Check Success! All Infected!\n'
# 9     b'Consistancy_Check Success! All Infected!\n'
# 10  b'Consistancy_Check Success! All Uninfected!\n'
# 11  b'Consistancy_Check Success! All Uninfected!\n'
#                    WALL                    CPU
#                    mean          max      mean       max
# ORDER SIZE
# 10    8        0.033761     0.033761  0.005879  0.005879
# 20    39       0.043434     0.043434  0.004316  0.004316
# 30    86       0.172633     0.172633  0.008902  0.008902
# 40    146      3.141817     3.141817  0.007865  0.007865
# 50    229      0.812128     0.812128  0.008145  0.008145
# 60    367    134.515531   134.515531  0.012911  0.012911
# 70    501   1059.856286  1059.856286  0.043646  0.043646
# 80    617    679.230123   679.230123  0.031596  0.031596
# 90    776     20.650742    20.650742  0.008465  0.008465
# 100   1010    28.810889    28.810889  0.009948  0.009948
# 110   1250     0.030857     0.030857  0.006732  0.006732
# 120   1425     0.172595     0.172595  0.007932  0.007932

# %% [markdown]
# ### connected_watts_strogatz_graph

# %%
scaling_data = pd.DataFrame(columns=['TYPE', 'ORDER', 'SIZE', 'WALL', 'CPU', 'RESULT'])
for x in range(0,1000):
    for i in range(4,6,1):
        order = 10*i
        k = math.ceil(2*order/100)
        p = 10**(-1)
        print(str("n: "+ str(order)), str("k: "+ str(k)) , str("p: "+ str(p)) )
        G = nx.watts_strogatz_graph(n=order, p=p, k = k, seed=i)
        nx.write_edgelist(G, path=str('../graph_data/processed/current_g'), data=False, delimiter='\t')
        WALL_START, CPU_START = time.time(), time.clock()
        p = subprocess.Popen(["/Users/trentonford/Repositories/RWWP/seq/./main"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=False)

        ## Talk with date command i.e. read data from stdout and stderr. Store this info in tuple ##
        ## Interact with process: Send data to stdin. Read data from stdout and stderr, until end-of-file is reached.  ##
        ## Wait for process to terminate. The optional input argument should be a string to be sent to the child process, ##
        ## or None, if no data should be sent to the child.
        (output, err) = p.communicate()

        p_status = p.wait()
        WALL_END, CPU_END = time.time(), time.clock()

        scaling_data_row = pd.DataFrame([["WATTS_STROGATZ", G.order(), G.size() ,WALL_END - WALL_START, CPU_END-CPU_START, output]], columns=['TYPE', 'ORDER', 'SIZE', 'WALL', 'CPU', 'RESULT'])
        scaling_data = scaling_data.append(scaling_data_row);

        print ("Command output : ", output)
        print ("Command exit status/return code : ", p_status)
scaling_data.reset_index(inplace=True)
scaling_data.drop(columns='index', inplace=True)
display(scaling_data)
scaling_data.to_pickle('1000_Watts_Strogatz_Scaling_data')
scaling_data.groupby(['ORDER','SIZE']).agg(['mean', 'max'])
# Out:
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :
# /Users/trentonford/Repositories/python3_7/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   # Remove the CWD from sys.path while we load stuff.
# /Users/trentonford/Repositories/python3_7/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# ...
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 40 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
# n: 50 k: 1 p: 0.1
# Command output :  b''
# Command exit status/return code :  -6
#                 TYPE ORDER SIZE      WALL       CPU RESULT
# 0     WATTS_STROGATZ     0    0  0.010370  0.011345    b''
# 1     WATTS_STROGATZ     0    0  0.007704  0.008276    b''
# 2     WATTS_STROGATZ     0    0  0.010707  0.011353    b''
# 3     WATTS_STROGATZ     0    0  0.005467  0.005870    b''
# 4     WATTS_STROGATZ     0    0  0.006036  0.006372    b''
# 5     WATTS_STROGATZ     0    0  0.005896  0.006371    b''
# 6     WATTS_STROGATZ     0    0  0.005516  0.005895    b''
# 7     WATTS_STROGATZ     0    0  0.005786  0.006168    b''
# 8     WATTS_STROGATZ     0    0  0.005725  0.006302    b''
# 9     WATTS_STROGATZ     0    0  0.006183  0.006706    b''
# 10    WATTS_STROGATZ     0    0  0.006177  0.006549    b''
# 11    WATTS_STROGATZ     0    0  0.005634  0.005899    b''
# 12    WATTS_STROGATZ     0    0  0.005983  0.006455    b''
# 13    WATTS_STROGATZ     0    0  0.005403  0.005923    b''
# 14    WATTS_STROGATZ     0    0  0.007231  0.007959    b''
# 15    WATTS_STROGATZ     0    0  0.006138  0.006442    b''
# 16    WATTS_STROGATZ     0    0  0.006004  0.006401    b''
# 17    WATTS_STROGATZ     0    0  0.005105  0.005536    b''
# 18    WATTS_STROGATZ     0    0  0.006732  0.007138    b''
# 19    WATTS_STROGATZ     0    0  0.005946  0.006257    b''
# 20    WATTS_STROGATZ     0    0  0.007635  0.008174    b''
# 21    WATTS_STROGATZ     0    0  0.007210  0.007757    b''
# 22    WATTS_STROGATZ     0    0  0.005829  0.006264    b''
# 23    WATTS_STROGATZ     0    0  0.004671  0.003386    b''
# 24    WATTS_STROGATZ     0    0  0.007349  0.008041    b''
# 25    WATTS_STROGATZ     0    0  0.006117  0.006572    b''
# 26    WATTS_STROGATZ     0    0  0.005326  0.003910    b''
# 27    WATTS_STROGATZ     0    0  0.008842  0.009379    b''
# 28    WATTS_STROGATZ     0    0  0.009219  0.006487    b''
# 29    WATTS_STROGATZ     0    0  0.006411  0.006906    b''
# ...              ...   ...  ...       ...       ...    ...
# 1970  WATTS_STROGATZ     0    0  0.006198  0.006548    b''
# 1971  WATTS_STROGATZ     0    0  0.006127  0.006587    b''
# 1972  WATTS_STROGATZ     0    0  0.005746  0.006117    b''
# 1973  WATTS_STROGATZ     0    0  0.005390  0.005830    b''
# 1974  WATTS_STROGATZ     0    0  0.006456  0.006511    b''
# 1975  WATTS_STROGATZ     0    0  0.005661  0.005995    b''
# 1976  WATTS_STROGATZ     0    0  0.007636  0.008165    b''
# 1977  WATTS_STROGATZ     0    0  0.006681  0.007069    b''
# 1978  WATTS_STROGATZ     0    0  0.006108  0.006536    b''
# 1979  WATTS_STROGATZ     0    0  0.005624  0.006010    b''
# 1980  WATTS_STROGATZ     0    0  0.007360  0.007667    b''
# 1981  WATTS_STROGATZ     0    0  0.007380  0.007678    b''
# 1982  WATTS_STROGATZ     0    0  0.006656  0.007238    b''
# 1983  WATTS_STROGATZ     0    0  0.006285  0.006598    b''
# 1984  WATTS_STROGATZ     0    0  0.006016  0.006774    b''
# 1985  WATTS_STROGATZ     0    0  0.007291  0.007654    b''
# 1986  WATTS_STROGATZ     0    0  0.008873  0.009055    b''
# 1987  WATTS_STROGATZ     0    0  0.007743  0.008336    b''
# 1988  WATTS_STROGATZ     0    0  0.013602  0.013805    b''
# 1989  WATTS_STROGATZ     0    0  0.007682  0.008749    b''
# 1990  WATTS_STROGATZ     0    0  0.006421  0.006814    b''
# 1991  WATTS_STROGATZ     0    0  0.005978  0.006415    b''
# 1992  WATTS_STROGATZ     0    0  0.005621  0.006033    b''
# 1993  WATTS_STROGATZ     0    0  0.005573  0.006010    b''
# 1994  WATTS_STROGATZ     0    0  0.005241  0.005828    b''
# 1995  WATTS_STROGATZ     0    0  0.005416  0.005800    b''
# 1996  WATTS_STROGATZ     0    0  0.006060  0.006703    b''
# 1997  WATTS_STROGATZ     0    0  0.006040  0.006579    b''
# 1998  WATTS_STROGATZ     0    0  0.005346  0.005793    b''
# 1999  WATTS_STROGATZ     0    0  0.005849  0.006852    b''
#
# [2000 rows x 6 columns]
#                 WALL                 CPU
#                 mean       max      mean       max
# ORDER SIZE
# 0     0     0.005943  0.013602  0.006357  0.013805

# %% [markdown]
# ### Complete Graph

# %%
scaling_data = pd.DataFrame(columns=['TYPE', 'ORDER', 'SIZE', 'WALL', 'CPU', 'RESULT'])
for x in range(0,1000):
    for i in range(2,6,1):
        G = nx.complete_graph(2**i, create_using=nx.DiGraph())
        nx.write_edgelist(G, path=str('../graph_data/processed/current_g'), data=False, delimiter='\t')
        WALL_START, CPU_START = time.time(), time.clock()
        p = subprocess.Popen(["/Users/trentonford/Repositories/RWWP/seq/./main"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=False)

        ## Talk with date command i.e. read data from stdout and stderr. Store this info in tuple ##
        ## Interact with process: Send data to stdin. Read data from stdout and stderr, until end-of-file is reached.  ##
        ## Wait for process to terminate. The optional input argument should be a string to be sent to the child process, ##
        ## or None, if no data should be sent to the child.
        (output, err) = p.communicate()

        p_status = p.wait()
        WALL_END, CPU_END = time.time(), time.clock()

        scaling_data_row = pd.DataFrame([["K", G.order(), G.size() ,WALL_END - WALL_START, CPU_END-CPU_START, output]], columns=['TYPE', 'ORDER', 'SIZE', 'WALL', 'CPU', 'RESULT'])
        scaling_data = scaling_data.append(scaling_data_row);

        print ("Command output : ", output)
        print ("Command exit status/return code : ", p_status)
scaling_data.reset_index(inplace=True)
scaling_data.drop(columns='index', inplace=True)
display(scaling_data)
scaling_data.to_pickle('1000_K_Scaling_data')
scaling_data.groupby(['ORDER','SIZE']).agg(['mean', 'max'])
# Out:
# /Users/trentonford/Repositories/python3_7/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c8ebac10a529> in <module>
#       5         nx.write_edgelist(G, path=str('../graph_data/processed/current_g'), data=False, delimiter='\t')
#       6         WALL_START, CPU_START = time.time(), time.clock()
# ----> 7         p = subprocess.Popen(["/Users/trentonford/Repositories/RWWP/seq/./main"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=False, env=my_env)
#       8
#       9         ## Talk with date command i.e. read data from stdout and stderr. Store this info in tuple ##
#
# NameError: name 'my_env' is not defined

# %%
import numpy as np
import scipy.stats

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m-h, m+h

# %%
scaling_data = pd.read_pickle('1000_K_Scaling_data')

# %%
scaling_data.WALL.values
# Out:
# array([0.03098226, 0.02838397, 0.07108307, ..., 0.02468991, 0.11879706,
#        0.27469373])

# %%
scaling_data.ORDER.unique()
# Out:
# array([4, 8, 16, 32], dtype=object)

# %%
import bootstrapped.bootstrap as bs
import bootstrapped.stats_functions as bs_stats

# %%
samples = scaling_data.loc[scaling_data.ORDER == 32].WALL.values

# %%
# calculate bootstrap estimates for the mean and standard deviation
mean_results = bs.bootstrap(samples, stat_func=bs_stats.mean)

# see advanced_bootstrap_features.ipynb for a discussion of how to use the stat_func arg
stdev_results = bs.bootstrap(samples, stat_func=bs_stats.std)

# %%
print('Bootstrapped mean should be: ')#.format(mean))
print('\t' + str(mean_results))
print('')
print('Bootstrapped stdev should be: ')#.format(stdev))
print('\t' + str(stdev_results))
# Out:
# Bootstrapped mean should be:
# 	1.0409216380119324    (0.971898806989193, 1.1076591499090194)
#
# Bootstrapped stdev should be:
# 	1.0912434870539252    (1.0097005410440782, 1.1759255389115395)

# %%
scaling_data.groupby(['ORDER','SIZE']).agg(['mean', 'max', mean_confidence_interval])
# Out:
#                 WALL                                                         \
#                 mean       max                     mean_confidence_interval
# ORDER SIZE
# 4     12    0.026777  0.045069  (0.02657257075920628, 0.026982026141733662)
# 8     56    0.035833  0.083681   (0.03528808965646426, 0.03637888536489805)
# 16    240   0.085254  0.304167   (0.08238999854400617, 0.08811838902160662)
# 32    992   1.040922  6.795367     (0.9731709826635656, 1.1086722933602993)
#
#                  CPU
#                 mean       max                      mean_confidence_interval
# ORDER SIZE
# 4     12    0.008225  0.012576  (0.008141547510365494, 0.008308588489635034)
# 8     56    0.008529  0.014697  (0.008429902483105463, 0.008628125516895511)
# 16    240   0.013958  0.038579    (0.013615750748231174, 0.0143007372517685)
# 32    992   0.098610  0.622035    (0.09251370860547511, 0.10470541339452616)
